# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np

import debiaswe as dwe
import debiaswe.we as we
from debiaswe.we import WordEmbedding

# %% [markdown]
# ## Part 1: Gender Bias in Word Embedding

# %%
# load google news word2vec
E = WordEmbedding('./embeddings/word_vectors.txt')
# Out:
# *** Reading data from ./embeddings/word_vectors.txt
# (376, 300)
# 376 words of dimension 300 : lakilaki, saksi, perdaganganorang, gangster, ..., disebarkan, korbanbegalpayudara, pemutilasi, peretasan
# 376 words of dimension 300 : lakilaki, saksi, perdaganganorang, gangster, ..., disebarkan, korbanbegalpayudara, pemutilasi, peretasan

# %% [markdown]
# ### Step 2: Define gender direction

# %%
# gender direction
v_gender = E.diff('perempuan', 'lakilaki')

# %% [markdown]
# ### Step 3: Generating analogies of "Man: x :: Woman : y"

# %%
# analogies gender
a_gender = E.best_analogies_dist_thresh(v_gender)

for (a,b,c) in a_gender:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 375.0
# Median: 375.0
# perempuan-lakilaki
# istri-suami
# tertembak-ditembak
# pengeroyokan-dikeroyok
# penusukan-ditusuk
# prajurit-komandan
# personel-organisasi
# menyelamatkan-menelantarkan
# mengkonsumsinarkotika-penyalahgunaannarkotika
# dicekik-mencekik
# bertahan-serangan
# diperiksa-diringkus
# perselingkuhan-berselingkuh
# pencemarannamabaik-namarusak
# muncikari-pelakutppo
# siswi-siswa
# dibentak-membentak
# diselidiki-penyelidikan
# dicopet-pencopetan
# melapor-dilaporkan
# korbantppo-perdaganganorang
# xviicenderawasih-kelompokkriminalbersenjata
# pengadilan-kpk
# dipimpin-memimpin
# digetokharga-menaikkanharga
# dibegal-begal
# diculik-menculik
# komplotan-pimpinan
# wanita-pria
# diancam-ancaman
# dipalak-memalak
# dievakuasi-tewas
# tembakan-penembakan
# menyembunyikantersangka-mengungkap
# satgas-kasatgas
# pelakunarkoba-kasusnarkoba
# penemuan-evakuasi
# pencurian-curanmor
# diracun-meracuni
# putri-putra
# ditetapkan-menetapkan
# dibacok-membacok
# keponakan-sepupu
# penumpang-maskapai
# pelanggan-jokites
# disiramairkeras-menyiramkanairkeras
# memproduksinarkoba-mengedarkannarkoba
# dibenarkan-bersalah
# tetangga-masyarakat
# diretas-peretasan
# arisanbodong-gangster
# karyawati-karyawan
# dirundung-perundungan
# pelakukdrt-korbankdrt
# bakutembak-kontaktembak
# tawuran-bentrokan
# bibi-paman
# aborsiilegal-mengevakuasi
# pengakuan-merespons
# dipaksa-adujotos
# dilecehkan-pelecehan
# tersandera-disandera
# provokasi-korbanpenganiayaan
# terlepas-tertangkap
# dibunuh-pelakupembunuhan
# teman-pacar
# korbanmutilasi-memutilasi
# mencuri-kehilangan
# diperkosa-pemerkosaan
# trauma-kekerasan
# dirampok-merampok
# termutilasi-pemutilasi
# integritas-korupsi
# saksi-tersangka
# korbankriminalitas-kriminal
# korbanpelecehan-melecehkan
# berupaya-pantauan
# saudari-saudara
# korbanpelurunyasar-menembak
# bunda-ayah
# prostitusi-kekerasanseksual
# laporan-terlapor
# upahtidakdibayar-penilapupah
# kenatipu-dukunpenggandauang
# berlindung-diserang
# menurut-membantah
# terbunuh-membunuh
# terancam-mengancam
# korbankekerasan-pelakukekerasanseksual
# korbanpencabulan-pencabulan
# penangkapan-ditangkap
# ibu-bapak
# ditipu-menipu
# berkatakasar-menampar
# korbanbegalpayudara-pelecehanseksual
# maling-pencuri
# warga-penjabat
# diteror-meneror
# berpestamiras-membawanarkoba
# negosiasi-menangani
# terbakar-pembakaran
# korbanbegal-membegal
# mahasiswi-mahasiswa
# mendalami-mengapresiasi
# korbanonlinescams-scamming
# kerugian-keuntungan
# menusuk-tertusuk
# penetapan-perdagangan
# ditodong-menodongkanpistol
# gendam-penipu
# resah-teror
# penipuan-tertipu
# membebaskan-penyanderaan
# pelarian-bersembunyi
# penyelamatan-persidangan
# korbantabraklari-pelakutabraklari
# penyidik-forensik
# senjataapiilegal-menangkap
# penuntut-dituntut
# diambil-mengambil
# membuangbayi-perdaganganorgan
# meringkus-gangguan
# diamankan-mengamankan
# kapolres-kepolisian
# pemerasan-diperas
# diproses-penegakan
# dikejar-pengejar
# pelayanan-permohonan
# konfirmasi-dikonfirmasi
# bersimbahdarah-pembunuhan
# menyerahkan-diserahkan
# wartawati-wartawan
# keamanan-membobol
# pengemudi-tertulis
# penistaanagama-penodaanagama
# meninggal-menyerang
# pemeranfilmporno-produksifilmporno
# ditangani-penanganan
# disebarkan-menyebar
# penyebaranhoax-pemalsuan
# dijambret-jambret
# dijual-menjual
# menjatuhkan-dijatuhkan
# separatis-teroris
# terlibat-lapangan
# selebgram-bersenjata
# dipukul-memukul
# dipungut-pungli
# pemakai-pengedar
# korbanperampokan-perampokan
# membawakaburmobil-kurirnarkoba
# terkenabacokan-bacokan
# simpatisan-pendukung
# bermotor-menjalani
# tergantung-menggantung
# mami-papi
# dijadikan-pedagang
# dibakar-membakar
# korbanperkosaan-memperkosa
# menderita-menyandera
# dianiaya-penganiayaan
# disekap-menyekap
# dikembalikan-berkoordinasi
# menyewapembunuh-dihabisipembunuh
# divhumas-jatanras
# terluka-melukai
# mengendarai-pembebasan
# ditabrak-menabrak
# dicabuli-mencabuli
# sekelompok-pendalaman
# akibat-sebab
# kericuhan-judionline
# difototanpabusana-berbuatmesum
# bikinonar-disidangkan
# korban-pelaku
# mengakibatkan-penyebab
# kebaikan-kejahatan
# pemudi-pemuda
# pembangunan-melaksanakan
# menyuap-menerimasuap
# teraniaya-menganiaya
# mendapatancaman-pengancaman
# sindikat-calo
# korbanpembacokan-pembacokan
# pengusutan-pasangan
# kementan-puskesmas

# %% [markdown]
# ## Debiasing Word Embedding

# %%
from debiaswe.debias import debias

# %%
# Lets load some gender related word lists to help us with debiasing
with open('./data/definitional_pairs.json', "r") as f:
    defs = json.load(f)
print("definitional", defs)

with open('./data/equalize_pairs.json', "r") as f:
    equalize_pairs = json.load(f)

with open('./data/gender_specific_seed.json', "r") as f:
    gender_specific_words = json.load(f)
print("gender specific", len(gender_specific_words), gender_specific_words[:10])
# Out:
# definitional [['perempuan', 'lakilaki'], ['wanita', 'pria'], ['ibu', 'bapak'], ['putri', 'putra'], ['bunda', 'ayah'], ['mami', 'papi'], ['pemudi', 'pemuda'], ['saudari', 'saudara']]
# gender specific 43 ['abang', 'ayah', 'ayahanda', 'bapak', 'bibi', 'boy', 'bunda', 'emak', 'gadis', 'girl']

# %%
debias(E, gender_specific_words, defs, equalize_pairs)
# Out:
# 376 words of dimension 300 : lakilaki, saksi, perdaganganorang, gangster, ..., disebarkan, korbanbegalpayudara, pemutilasi, peretasan
# {('Saudara', 'Saudari'), ('PEMUDA', 'PEMUDI'), ('SAUDARA', 'SAUDARI'), ('siswa', 'siswi'), ('papi', 'mami'), ('Pria', 'Wanita'), ('Paman', 'Bibi'), ('Lakilaki', 'Perempuan'), ('Mahasiswa', 'Mahasiswi'), ('saudara', 'saudari'), ('MAHASISWA', 'MAHASISWI'), ('PAMAN', 'BIBI'), ('LELAKI', 'PEREMPUAN'), ('Putra', 'Putri'), ('Pemuda', 'Pemudi'), ('Ayah', 'Ibu'), ('karyawan', 'karyawati'), ('SUAMI', 'ISTRI'), ('Suami', 'Istri'), ('Karyawan', 'Karyawati'), ('Siswa', 'Siswi'), ('ayah', 'bunda'), ('pemuda', 'pemudi'), ('Wartawan', 'Wartawati'), ('putra', 'putri'), ('lelaki', 'perempuan'), ('suami', 'istri'), ('ayah', 'ibu'), ('PAPI', 'MAMI'), ('wartawan', 'wartawati'), ('mahasiswa', 'mahasiswi'), ('paman', 'bibi'), ('SISWA', 'SISWI'), ('PUTRA', 'PUTRI'), ('Lelaki', 'Perempuan'), ('AYAH', 'IBU'), ('AYAH', 'BUNDA'), ('lakilaki', 'perempuan'), ('PRIA', 'WANITA'), ('WARTAWAN', 'WARTAWATI'), ('Ayah', 'Bunda'), ('KARYAWAN', 'KARYAWATI'), ('Papi', 'Mami'), ('LAKILAKI', 'PEREMPUAN'), ('pria', 'wanita')}
# 376 words of dimension 300 : lakilaki, saksi, perdaganganorang, gangster, ..., disebarkan, korbanbegalpayudara, pemutilasi, peretasan

# %%
# analogies gender
a_gender_debiased = E.best_analogies_dist_thresh(v_gender)

for (a,b,c) in a_gender_debiased:
    print(a+"-"+b)
# Out:
# Computing neighbors
# Mean: 375.0
# Median: 375.0
# perempuan-suami
# lakilaki-istri
# tertembak-ditembak
# pengeroyokan-dikeroyok
# penusukan-ditusuk
# prajurit-komandan
# personel-organisasi
# menyelamatkan-menelantarkan
# mengkonsumsinarkotika-penyalahgunaannarkotika
# dicekik-mencekik
# bertahan-serangan
# diperiksa-diringkus
# pencemarannamabaik-pelakutppo
# perselingkuhan-berselingkuh
# muncikari-namarusak
# dibentak-membentak
# diselidiki-penyelidikan
# dicopet-pencopetan
# melapor-dilaporkan
# korbantppo-perdaganganorang
# xviicenderawasih-kelompokkriminalbersenjata
# pengadilan-kpk
# dipimpin-memimpin
# diculik-begal
# digetokharga-menaikkanharga
# dibegal-memalak
# komplotan-pimpinan
# diancam-ancaman
# dievakuasi-sepupu
# diracun-menculik
# satgas-kasatgas
# dipalak-tewas
# tembakan-penembakan
# menyembunyikantersangka-mengungkap
# pencurian-curanmor
# pelakunarkoba-kasusnarkoba
# penemuan-evakuasi
# ditetapkan-menetapkan
# dibacok-membacok
# keponakan-maskapai
# disiramairkeras-meracuni
# penumpang-melecehkan
# pelanggan-jokites
# memproduksinarkoba-mengedarkannarkoba
# dibenarkan-bersalah
# dirundung-perundungan
# diretas-peretasan
# arisanbodong-gangster
# tetangga-masyarakat
# aborsiilegal-menyiramkanairkeras
# pelakukdrt-bentrokan
# bakutembak-kontaktembak
# dipaksa-korbankdrt
# tawuran-adujotos
# provokasi-mengevakuasi
# dilecehkan-korbanpenganiayaan
# pengakuan-merespons
# tersandera-disandera
# terlepas-tertangkap
# korbanmutilasi-pelecehan
# dibunuh-pelakupembunuhan
# teman-merampok
# diperkosa-pemerkosaan
# berupaya-kehilangan
# trauma-kekerasan
# dirampok-pacar
# termutilasi-pemutilasi
# mencuri-tersangka
# korbanpelecehan-korupsi
# korbankriminalitas-kriminal
# korbanpelurunyasar-menembak
# berlindung-pantauan
# laporan-terlapor
# integritas-membunuh
# prostitusi-kekerasanseksual
# saksi-menampar
# terancam-dukunpenggandauang
# upahtidakdibayar-penilapupah
# menurut-membantah
# warga-mengancam
# korbanbegalpayudara-memutilasi
# kenatipu-pencuri
# korbankekerasan-diserang
# korbanpencabulan-pencabulan
# penangkapan-ditangkap
# berpestamiras-pelakukekerasanseksual
# mendalami-pelecehanseksual
# ditipu-penjabat
# maling-menangani
# diteror-meneror
# ayah-bapak
# terbakar-menipu
# berkatakasar-membawanarkoba
# negosiasi-pembakaran
# korbanbegal-membegal
# kerugian-mengapresiasi
# korbanonlinescams-scamming
# penyelamatan-menodongkanpistol
# menusuk-keuntungan
# diambil-perdagangan
# terbunuh-forensik
# gendam-penipu
# resah-teror
# penipuan-tertipu
# penetapan-persidangan
# diamankan-penyanderaan
# korbantabraklari-tertusuk
# ditodong-menangkap
# pelarian-bersembunyi
# penuntut-pelakutabraklari
# membebaskan-wanita
# membuangbayi-gangguan
# pemerasan-dituntut
# senjataapiilegal-mengamankan
# meringkus-permohonan
# bersimbahdarah-mengambil
# kapolres-kepolisian
# diproses-penegakan
# menyerahkan-diperas
# konfirmasi-perdaganganorgan
# dikejar-pengejar
# pengemudi-dikonfirmasi
# penyidik-diserahkan
# meninggal-membobol
# penistaanagama-karyawati
# pelayanan-produksifilmporno
# pemeranfilmporno-bibi
# keamanan-tertulis
# ibu-bunda
# dijambret-menyerang
# ditangani-penanganan
# dijual-pembunuhan
# disebarkan-penodaanagama
# penyebaranhoax-pemalsuan
# dipukul-menyebar
# menjatuhkan-teroris
# selebgram-saudari
# terlibat-lapangan
# separatis-pungli
# pemudi-menjalani
# mahasiswi-jambret
# bermotor-wartawati
# membawakaburmobil-memukul
# pemakai-dijatuhkan
# dipungut-kurirnarkoba
# dijadikan-putra
# wartawan-menjual
# terkenabacokan-bacokan
# mami-pengedar
# korbanperampokan-bersenjata
# putri-pria
# dibakar-perampokan
# simpatisan-membakar
# tergantung-menggantung
# dicabuli-siswa
# menderita-memperkosa
# dianiaya-penganiayaan
# siswi-pendukung
# korbanperkosaan-menyandera
# ditabrak-pemuda
# dikembalikan-berkoordinasi
# disekap-melukai
# mengendarai-pedagang
# difototanpabusana-menyekap
# divhumas-jatanras
# sekelompok-mahasiswa
# menyewapembunuh-dihabisipembunuh
# saudara-pembebasan
# terluka-papi
# akibat-sebab
# kericuhan-mencabuli
# kebaikan-menabrak
# korban-pendalaman
# paman-judionline
# bikinonar-disidangkan
# teraniaya-pelaku
# mendapatancaman-ibu
# menyuap-kejahatan
# mengakibatkan-penyebab
# karyawan-melaksanakan
# sindikat-berbuatmesum
# pembangunan-calo
# dinyatakan-menerimasuap
# korbanpembacokan-pengancaman
# pengusutan-menganiaya
# kementan-puskesmas
# polhukam-pembacokan
# memeras-cabul

# %%
E.save('output')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 E.save('output')
#
# File d:\D\Dokumennnnn\New folder (4)\Music\debiaswe-master\debiaswe\we.py:119, in WordEmbedding.save(self, filename)
#     117 def save(self, filename):
#     118     filename = "output.txt"
# --> 119     with open(filename, "w") as f:
#     120         f.write("\n".join([w + " " + " ".join([str(x) for x in v]) for w, v in zip(self.words, self.vecs)]))
#     121         f.close()  # This is redundant, but added for explicitness
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output.txt'

# %%
E.vecs
